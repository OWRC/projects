# %% [markdown]
# # Update Raven HRUs
#
# This script is used to update the Raven HRU definition file (*.rvh) according to a given land use map. This script would be run should the user wish to alter land use patterns and compare model outputs to the baseline conditions and asses how land use change can potentially affect local hydrology.
#
# After completion of this script, lines are printed that are to be copy-and-pasted into the the Raven *HRU/Basin Definition file* (.rvh).
#
# The simplest way to use this file is to alter the land use raster file name and click the `Run All` button. A text files with the necessary lines needed to be pasted into the model .rvh file will be created.

# %% [markdown]
# ## Load Python packages and import data

# %%
import os
import math
import numpy as np
import shapefile
from pyproj import Proj
from PIL import Image, ImageDraw

# %% [markdown]
# ### Import data, set user settings
#
# This script requires 4 datasets + 1 user setting:
#
# 1. The sub-basin polygon shapefile--*this must <ins>not</ins> be modified for this script to work*
# 1. A digital elevation model (DEM)--*it is unlikely that this will need changing*
# 1. Surficial geology mapping--*this too will unlikely need changing*
# 1. Land use mapping--*This is the target raster that would need changing for the execution of this script*
# 1. minHRUfraction--*more on the purpose of the parameter below, can be changed but the value of 0.05 was maintained throughout the 2025 water balance study*
#
# > All of the above files must be altered (where necessary) external, and prior to the execution, of this script. These input files are standard GIS files and should be altered by GIS professionals.

# %% [markdown]
# #### Files paths to alter
# Land us cover--details of raster specifications are given below

# %%
lufp = '../GIS/CH_Landuse_dissolved.bil' # land use raster

# %% [markdown]
# #### File paths and Parameters that may be altered
# inputs not likely/recommended to change

# %%
demfp = '../GIS/PDEM-South-D2013-OWRC23-60_resmpl.bil' # digital elevation model
sgfp = '../GIS/surfgeo23_60_resmpl.bil' # surficial geology raster

# %% [markdown]
# Script parameters (more details below)

# %%
minHRUfraction = 0.05 # recommended to be kept at 0.05

# %% [markdown]
# #### File path <ins>not</ins> to change
# > Doing so may results in Raven model errors

# %%
sbasfp = '../GIS/CH_Subwatershed_select.shp' # modified CH sub-watershed boundaries

# %% [markdown]
# ### Notes:
# Please note that all input rasters must conform to th following pre-determined raster definition and projection.

# %% [markdown]
# #### Projection:
#
# [EPSG:3161 - NAD83/Ontario MNR Lambert](https://epsg.io/3161):
#
# ```
# PROJCS["NAD83 / Ontario MNR Lambert",
#     GEOGCS["NAD83",
#         DATUM["North_American_Datum_1983",
#             SPHEROID["GRS 1980",6378137,298.257222101],
#             TOWGS84[0,0,0,0,0,0,0]],
#         PRIMEM["Greenwich",0,
#             AUTHORITY["EPSG","8901"]],
#         UNIT["degree",0.0174532925199433,
#             AUTHORITY["EPSG","9122"]],
#         AUTHORITY["EPSG","4269"]],
#     PROJECTION["Lambert_Conformal_Conic_2SP"],
#     PARAMETER["latitude_of_origin",0],
#     PARAMETER["central_meridian",-85],
#     PARAMETER["standard_parallel_1",44.5],
#     PARAMETER["standard_parallel_2",53.5],
#     PARAMETER["false_easting",930000],
#     PARAMETER["false_northing",6430000],
#     UNIT["metre",1,
#         AUTHORITY["EPSG","9001"]],
#     AXIS["Easting",EAST],
#     AXIS["Northing",NORTH],
#     AUTHORITY["EPSG","3161"]]
# ```

# %% [markdown]
# #### Raster Grid Definition:
#
# [ESRI Band interleaved by line files (_*.bil_)](https://desktop.arcgis.com/en/arcmap/latest/manage-data/raster-and-images/bil-bip-and-bsq-raster-files.htm) are used in this script. These binary raster files must be accompanied with a grid definition header file (_*.hdr_) with the following spatial attributes:
#
# ```
# NROWS          719
# NCOLS          726
# ULXMAP         1323330
# ULYMAP         11906070
# XDIM           60
# YDIM           60
# NODATA         -9999
# ```

# %%
# (keep consistent with input raster definition)
nrows = 719
ncols = 726
xul = 1323330
yul = 11906070
cs = 60. # grid cell width
epsg=3161

# %% [markdown]
# ### Read data

# %% [markdown]
# #### Functions
#
# The following are a set of functions needed to process the input data, *please do not alter these*. (Note that grid definition specification has been hard-coded into the functions.)

# %%
# Reads integer rasters
def readIntRaster(fp):
    aa = np.fromfile(fp,np.int32)
    if len(aa) == nrows*ncols:
        x = dict(zip(np.arange(nrows*ncols),aa))
    elif len(aa) == nrows*ncols/2:
        aa = np.fromfile(fp,np.int16)
        x = dict(zip(np.arange(nrows*ncols),aa))
    else:
        print(" ** Warning, unknown raster size {}",fp)
        return None
    return x

# Reads real-number rasters
def readFloatRaster(fp):
    aa = np.fromfile(fp,np.float32)
    aa[aa<-9999] = -9999
    if len(aa) == nrows*ncols:
        x = dict(zip(np.arange(nrows*ncols),aa))
    else:
        print(" ** Warning, unknown raster size {}",fp)
        return None
    return x

# saves binary raster
def saveBinaryInt(fp, dat):
    fn, _ = os.path.splitext(fp)
    with open(fn+'.hdr', 'w') as f: # save header
        f.write('BYTEORDER      I\n')
        f.write('LAYOUT         BIL\n')
        f.write('NROWS          '+str(nrows)+'\n')
        f.write('NCOLS          '+str(ncols)+'\n')
        f.write('NBANDS         1\n')
        f.write('NBITS          32\n')
        f.write('BANDROWBYTES   '+str(nrows*4)+'\n')
        f.write('TOTALROWBYTES  '+str(nrows*4)+'\n')
        f.write('PIXELTYPE      SIGNEDINT32\n')
        f.write('ULXMAP         '+str(xul+cs/2)+'\n') # The x-axis map coordinate of the center of the upper-left pixel.
        f.write('ULYMAP         '+str(yul-cs/2)+'\n') # The y-axis map coordinate of the center of the upper-left pixel.
        f.write('XDIM           '+str(cs)+'\n')
        f.write('YDIM           '+str(cs)+'\n')
        f.write('NODATA         -9999\n')
    def crc(c): # cell to row-col
        i = int(cid/ncols)
        j = c - i*ncols
        return (i,j)

    if type(dat)==dict:
        a = np.full((nrows,ncols),-9999,dtype=np.int32)
        for cid,v in dat.items(): a[crc(cid)] = np.int32(v)
        if os.path.exists(fp): os.remove(fp)
        a.tofile(fp) # always saved in C-order (row-major)
    # elif type(dat)==np.ndarray:
    #     if os.path.exists(fp): os.remove(fp)            
    #     dat.tofile(fp)
    else:
        print('saveBinaryInt error, unsupported type:',type(dat))

# %%
# get cell slopes and aspect from DEM
def slopeAspectTarboton(x):
    #  ref: Tarboton D.G., 1997. A new method for the determination of flow directions and upslope areas in grid digital elevation models. Water Resources Research 33(2). p.309-319.
    #  triangular facets, ordered by steepest (assumes uniform cells)
    #  facets (slightly modified from Tarboton, 1997):
    #         \2|1/
    #         3\|/0
    #         --+--
    #         4/|\7
    #         /5|6\        
    re1 = [0, -1, -1, 0, 0, 1, 1, 0]
    ce1 = [1, 0, 0, -1, -1, 0, 0, 1]
    re2 = [-1, -1, -1, -1, 1, 1, 1, 1]
    ce2 = [1, 1, -1, -1, -1, -1, 1, 1]
    ac = [0., 1., 1., 2., 2., 3., 3., 4.]
    af = [1., -1., 1., -1., 1., -1., 1., -1.]
    atan1 = math.atan(1.)  #math.Atan(1.)
    hcw = math.sqrt(2 * cs**2)
    
    sxs, rgs = dict(), dict()
    for cid,e0 in x.items():
        sx, rx, kx = 0., -9999, -1
        for k in range(8):
            c1, c2 = cid+re1[k]*ncols+ce1[k], cid+re2[k]*ncols+ce2[k]
            if not c1 in x: continue
            if not c2 in x: continue
            e1, e2 = x[c1], x[c2]
            if e1==-9999 or e2==-9999: continue
            if e1 > e0 and e2 > e0: continue

            s1 = (e0 - e1) / cs
            s2 = (e1 - e2) / cs
            r = math.atan2(s2,s1)
            s = math.sqrt(s1**2 + s2**2)
            if r < 0:
                r = 0
                s = s1
            elif r > atan1:
                r = atan1
                s = (e0 - e2) / hcw

            if s > sx:
                sx = s
                rx = r
                kx = k
        
        if kx < 0:
            sxs[cid], rgs[cid] = 0., -9999. # unspecified
            continue

        rg = af[kx]*rx + ac[kx]*math.pi/2.
        if rg > math.pi: rg -= 2 * math.pi # [-pi,pi]

        sxs[cid], rgs[cid] = sx, rg

    return sxs, rgs

# %%
# Get raster grid cells within sub-watershed polygons
def polygonToCellIDs(pts):
    img = Image.new('L', (ncols, nrows), 0)
    offset = [xul, yul-nrows*cs]
    pixelpoly = [((x-offset[0])/cs, nrows-(y-offset[1])/cs) for x,y in pts]
    ImageDraw.Draw(img).polygon(pixelpoly, outline=1, fill=1)
    mask = np.array(img)
    return list(np.arange(nrows*ncols)[mask.reshape(nrows*ncols)>0])

def loadSWS(fp):
    sf = shapefile.Reader(fp)
    geom = sf.shapes()
    attr = sf.records()
    xr = dict()
    lak = dict()
    csws = dict()
    for i in range(len(geom)):
        a = attr[i]
        sid = int(a.SubId)
        lak[sid] = a.lake != 0
        pcids = polygonToCellIDs(geom[i].points)
        for pc in pcids:
            if pc in csws:
                csws[pc].append(sid)
            else:
                csws[pc] = [sid]
        xr[sid] = [int(pc) for pc in pcids]

    # the polygonToCellIDs function can cause overlap where 2 adjacent polygons are assigned the same cell
    for c, sids in csws.items():
        if len(sids)<2: continue
        cmin, smin = 2**63-1 , -1
        for sid in sids:
            if len(xr[sid]) < cmin:
                cmin = len(xr[sid])
                smin = sid
        for sid in sids:
            if sid==smin: continue
            xr[sid].remove(c)

    return xr, lak

# %%
# special function to report raster data ranges
def crange(x):
    vv = [v for _, v in x.items()]
    print("[{},{}]".format(min(vv),max(vv)))

# %% [markdown]
# #### Data
#
# Below all of
#
# - DEM, land use, surficial geology are loaded
# - Slopes and aspected are computed
# - Cell indexing of sub-basin is determined

# %%
# Get cell elevations, slopes and aspects, cross-referenced to cell ID
elevations = readFloatRaster(demfp)
slopes, aspects = slopeAspectTarboton(elevations) # Note: this function will return a "RuntimeWarning: overflow encountered in scalar power s = math.sqrt(s1**2 + s2**2)" Please ignore

crange(elevations)
crange(slopes)
crange(aspects)
# Out:
# [-9999.0,414.9754943847656]
# [0.0,4.668233313305587]
# [-9999.0,3.141592653589793]

# %%
# Sub-basins cross-referenced to cell ID, and flag whether the sub-basin is of lake/reservoir type
xsb, islak = loadSWS(sbasfp)

# %%
# Read land use and surficial geology, cross-referenced to cell ID
xlu = readIntRaster(lufp)
xsg = readIntRaster(sgfp)
crange(xlu)
crange(xsg)
# Out:
# [-9999,11]
# [0,200]

# %% [markdown]
# ## Set Properties to Land use and Surficial Geology

# %% [markdown]
# ### Land use
#
# Land use provided by Conservation Halton is categorized into 11 classes. From these, a land surface type and a canopy type are assigned.
#
# > When creating a new land use map to model, the map <ins>must</ins> conform to these 11 classes.
#
# | ID | Class description | Land surface type | Canopy type |
# |:---|:---|:---|:---|
# 1 | Forest | Forest | Deciduous |
# 2 | Hedge Row | Short vegetation | Mixed vegetation |
# 3 | Marsh | Wetland | Short vegetation |
# 4 | Swamp | Swamp | Short vegetation |
# 5 | Forested Swamp | Swamp | Mixed vegetation |
# 6 | Water | Waterbody | Bare |
# 7 | Agriculture | Agriculture | Short vegetation |
# 8 | Undifferentiated | Short vegetation | Short vegetation |
# 9 | Settlement and Developed Lands | Urban | Bare |
# 10 | Transportation | Barren | Bare |
# 11 | Extraction-Aggregate | noflow | Bare |

# %%
# used to convert CH land use ID to surface/canopy type
chlu = {
        1: ("Forest", "Deciduous"), # Forest
        2: ("ShortVegetation", "MixedVegetation"), # Hedge Row
        3: ("Wetland", "ShortVegetation"), # Marsh
        4: ("Swamp", "ShortVegetation"), # Swamp
        5: ("Swamp", "MixedVegetation"), # Forested Swamp
        6: ("Waterbody", "Bare"), # Water
        7: ("Agriculture", "ShortVegetation"), # Agriculture
        8: ("ShortVegetation", "ShortVegetation"), # Undifferentiated
        9: ("Urban", "Bare"), # Settlement and Developed Lands
        10: ("Barren", "Bare"), # Transportation
        11: ("noflow", "Bare"), # Extraction-Aggregate
    }
def chToTuple(x):
    o = dict()
    for c,v in x.items(): 
        if v < 0:
            o[c] = chlu[8] # default unknown/unspecified to Undifferentiated
        else:
            o[c] = chlu[v]
    return o

# %% [markdown]
# ### Surficial geology
#
# Surficial geology was obtained from Ontario Geological Survey (OGS) Surficial geology of southern Ontario. Full description can be found [here](https://owrc.github.io/interpolants/interpolation/surfgeo.html) and the source metadata can be found [here](https://owrc.github.io/metadata/surfaces/surficial_geology.html).  The input surficial geology raster is organized by the geologic type, the following table shows the relationship between material type and the relative permeability attribute assigned by the OGS:
#
# | Raster ID | Relative Permeability | Material type |
# |:---|:---|:---|
# | 0 | Variable | Waterbody |
# | 10 | Low | Precambrian bedrock |
# | 20 | Low | Bedrock-drift complex in Precambrian terrain |
# | 21 | Low | Bedrock-drift complex in Precambrian terrain: Primarily till cover |
# | 22 | Low | Bedrock-drift complex in Precambrian terrain: Primarily stratified drift cover |
# | 30 | Variable | Sedimentary (Paleozoic) bedrock |
# | 40 | Variable | Bedrock-drift complex in Paleozoic terrain |
# | 41 | Variable | Bedrock-drift complex in Paleozoic terrain: Primarily till cover |
# | 50 | Medium | Till (Diamicton) |
# | 51 | Medium | Till: Silty sand to sand-textured till on Precambrian terrain |
# | 52 | LowMedium | Till: Stone-poor, sandy silt to silty sand-textured till on Paleozoic terrain |
# | 53 | Medium | Till: Stony, sandy silt to silty sand-textured till on Paleozoic terrain |
# | 54 | Low | Till: Clay to silt-textured till (derived from glaciolacustrine deposits or shale) |
# | 55 | Variable | Till: Undifferentiated older tills, may include stratified deposits |
# | 60 | High | Ice-contact stratified deposits |
# | 61 | High | Ice-contact stratified deposits: In moraines, eskers, kames and crevasse fills |
# | 62 | High | Ice-contact stratified deposits: In subaquatic fans |
# | 70 | High | Glaciofluvial deposits: Sandy deposits |
# | 71 | High | Glaciofluvial deposits: Gravelly deposits |
# | 72 | High | Glaciofluvial deposits |
# | 80 | Low | Fine-textured glaciolacustrine deposits |
# | 81 | Low | Fine-textured glaciolacustrine deposits: Massive to well laminated |
# | 82 | Low | Fine-textured glaciolacustrine deposits: Interbedded silt and clay and gritty, pebbly flow till and rainout deposits |
# | 90 | High | Coarse-textured glaciolacustrine deposits |
# | 91 | High | Coarse-textured glaciolacustrine deposits: Deltaic deposits |
# | 92 | High | Coarse-textured glaciolacustrine deposits: Littoral deposits |
# | 93 | High | Coarse-textured glaciolacustrine deposits: Foreshore and basinal deposits |
# | 120 | Fluvial | Older alluvial deposits |
# | 130 | Low | Fine-textured lacustrine deposits |
# | 140 | High | Coarse-textured lacustrine deposits |
# | 142 | High | Coarse-textured lacustrine deposits: Littoral deposits |
# | 143 | High | Coarse-textured lacustrine deposits: Foreshore and basinal deposits |
# | 170 | MediumHigh | Eolian deposits |
# | 190 | Fluvial | Modern alluvial deposits |
# | 200 | Organic | Organic Deposits |
# | 210 | Variable | Fill |
#
#
# From the above table, this layer is subdivided into 8 classes based on permeability attribute:
#
# | ID | Relative Permeability |
# |:---|:---|
# | 1 | Low |
# | 2 | Low Medium |
# | 3 | Medium |
# | 4 | Medium High |
# | 5 | High |
# | 6 | Unknown/variable |
# | 7 | Streambed/fluvial/floodplain |
# | 8 | Wetland sediments/organics |

# %%
# used to convert OGS ID to relative permeability
permlu = {
        1: 'Low',       
        2: 'LowMedium',
        3: 'Medium',
        4: 'MediumHigh',
        5: 'High',
        6: 'Unknown',
        7: 'Streambed',
        8: 'WetlandSediments',
    }
def ogsToRelPerm(x):
    o = dict()
    for c,v in x.items():
        match v:
            case 10 | 20 | 21 | 22 | 54 | 80 | 81 | 82 | 130:
                o[c] = permlu[1] # 'Low'
            case 52:
                o[c] = permlu[2] # 'LowMedium'
            case 50 | 51 | 53:
                o[c] = permlu[3] # 'Medium'
            case 170:
                o[c] = permlu[4] # 'MediumHigh'
            case 60 | 61 | 62 | 70 | 71 | 72 | 90 | 91 | 92 | 93 | 140 | 142 | 143:
                o[c] = permlu[5] # 'High'
            case 0 | 30 | 40 | 41 | 55 | 210:
                o[c] = permlu[6] # 'Variable'
            case 120 | 190:
                o[c] = permlu[7] # 'Fluvial'
            case 200:
                o[c] = permlu[8] # 'Organic'
            case _:
                print(' WARNING: no SG data for type {}'.format(v))
    return o

# %%
# update integer refernce to character reference for both land use and soil types
xlu = chToTuple(xlu)
xsg = ogsToRelPerm(xsg)

# %% [markdown]
# ### Raster Overlay Grouping
#
# The next step is to perform a raster overlay exercise to group combinations land use, surficial geology and sub-basin ID; it is from these groupings where Raven HRUs are derived. In order to optimize model runtimes, it is a good idea to aggregate those groupings that cover small portions of a sub-basin. Here, we declare that any group proportionally covering a sub-basin that is less than the user-defined parameter `minHRUfraction` be aggregated.
#
# > For the Conservations Halton 2025 water budget, `minHRUfraction` is set to 5%.
#
# The aggregation of small-proportion combinations is then broken up into a maximum of 4 distinct land use classes covering an assumed relative permeability class:
#
# 1. Urban areas (ID: 9; variable permeability: 6)
# 1. Wetlands (ID: 3--5; Wetland sediments: 8)
# 1. Agriculture (ID: 7; variable permeability: 6)
# 1. Natural (ID: all else; variable permeability: 6)

# %% [markdown]
# #### Funtions

# %%
def buildHRUs(sbc, slak, lu, sg, zc, gc, ac):
    prj = Proj('EPSG:'+str(epsg))
    hrus = dict() # swsid: (lu,sg): fractional cover
    llzga = dict() # swsid: (lu,sg): (lat,long,elev,slope-angle,aspect)
    cells = dict() # cellid: (lu,sg)
    
    cc = 0
    for sid,cids in sbc.items():
        dt, xt, yt, zt, gt, axt, ayt, gnt = dict(), dict(), dict(), dict(), dict(), dict(), dict(), dict()
        n = len(cids)
        for c in cids:

            # HARD-CODED DEFAULTS
            ll = chlu[8]
            gg = permlu[6]
            
            if c in lu: ll = lu[c]
            if c in sg: gg = sg[c]
            t = (ll,gg)
            cells[c] = t

            # collect elevations and centroids per hru
            ii = int(c/ncols)
            jj = c - ii*ncols
            if zc[c]>-999:
                if t in dt: 
                    dt[t] += 1 
                    xt[t] += xul+(jj+0.5)*cs
                    yt[t] += yul-(ii+0.5)*cs
                    zt[t] += zc[c] # sum elevation
                else: 
                    dt[t] = 1
                    xt[t] = xul+(jj+0.5)*cs
                    yt[t] = yul-(ii+0.5)*cs          
                    zt[t] = zc[c]

            # collect slopes and aspects per hru
            if gc[c] > 0:
                if t in gt:
                    gnt[t] += 1
                    gt[t] += math.atan(gc[c]) # sum slopes (convert rise/run to angle)
                    axt[t] += math.sin(ac[c]) # sum x-component of aspect
                    ayt[t] += math.cos(ac[c]) # sum y-component of aspect
                else:
                    gnt[t] = 1
                    gt[t] = math.atan(gc[c])
                    axt[t] = math.sin(ac[c])
                    ayt[t] = math.cos(ac[c])

        if slak[sid]: # setting sub-basin as a lake HRU
            hrus[sid] = "lake"
            sx, sy, sz, sd = 0., 0., 0., 0.
            for t,dd in dt.items():
                sd += dd
                sx += xt[t]
                sy += yt[t]
                sz += zt[t]

            lng,lat = prj(sx/sd, sy/sd, inverse=True)
            llzga[sid] = (lat,lng,float(sz/sd))
            cc+=1
        else:
            dd, sa = dict(), dict()
            x, y, z, g, ax, ay, gn = dict(), dict(), dict(), dict(), dict(), dict(), dict()
            def aggregate(t,tg,v,cidm=None):                            
                if tg in dd:
                    dd[tg] += v
                    x[tg] += xt[t]
                    y[tg] += yt[t]
                    z[tg] += zt[t]
                    if t in gnt and gnt[t]>0:
                        g[tg] += gt[t]
                        gn[tg] += gnt[t]
                        ax[tg] += axt[t]
                        ay[tg] += ayt[t]
                else:
                    dd[tg] = v
                    x[tg] = xt[t]
                    y[tg] = yt[t]
                    z[tg] = zt[t]
                    if t in gnt and gnt[t]>0:
                        g[tg] = gt[t]
                        gn[tg] = gnt[t]
                        ax[tg] = axt[t]
                        ay[tg] = ayt[t]
                if cidm is not None:
                    for c in cidm: cells[c]=tg  

            for t,v in dt.items():
                if v/n > minHRUfraction: # large combination, keep as-is
                    aggregate(t,t,v)
                else:                    # small combination, aggregate to general groups
                    cidm = list()
                    for c in cids: 
                        if cells[c]==t: cidm.append(c)          
                    match t[0]:
                        case 9: # urban
                            aggregate(t,(chlu[9],permlu[6]),v,cidm)
                        case 7: # agriculture
                            aggregate(t,(chlu[7],permlu[6]),v,cidm)
                        case 3 | 4 | 5: # wetland
                            aggregate(t,(chlu[3],permlu[8]),v,cidm)
                        case _: # other/natural
                            aggregate(t,(chlu[8],permlu[6]),v,cidm)
            
            for t,v in dd.items(): 
                dd[t]/=n # normalize
                lng,lat = prj(x[t]/v, y[t]/v, inverse=True)
                if not t in gn or gn[t]==0:
                    sa[t] = (lat,lng,float(z[t]/v),0.,0.)
                else:
                    gg = g[t]/gn[t] # radians
                    aa = (math.atan2(ax[t]/gn[t],ay[t]/gn[t]) + 2 * np.pi) % (2 * np.pi) # [0 to 2pi]
                    sa[t] = (lat,lng,float(z[t]/v),gg,aa)

            hrus[sid] = dd
            llzga[sid] = sa
            cc += len(dd)

    print(' {} distinct HRUs'.format(cc))

    return hrus, llzga, cells

# %%
def printHRUIDs(fp, sbc, hrus, cells):
    d = dict()
    tt = dict()
    c = 0
    for sid,lusg in hrus.items():
        if lusg=='lake':
            c+=1
            for cid in sbc[sid]: d[cid] = c

    for sid,lusg in hrus.items():
        if lusg=='lake': continue
        tt[sid] = dict()
        for t,_ in lusg.items():
            c+=1
            tt[sid][t] = c

    for sid,cids in sbc.items():
        if not sid in tt: continue
        for c in cids:
            t = cells[c]
            d[c] = tt[sid][t]

    saveBinaryInt(fp,d)

# %% [markdown]
# #### Processing
#
# Build HRUs and output an HRU ID raster for later reference (i.e., the *output_to_raster.ipynb* script)

# %%
hrus, llzga, cells = buildHRUs(xsb,islak,xlu,xsg,elevations,slopes,aspects)
printHRUIDs(lufp[:-4]+'-hruid.bil',xsb,hrus,cells) # Save HRU ID as raster
# Out:
#  420 distinct HRUs
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[19], line 2
#       1 hrus, llzga, cells = buildHRUs(xsb,islak,xlu,xsg,elevations,slopes,aspects)
# ----> 2 printHRUIDs(lufp[:-4]+'-hruid.bil',xsb,hrus,cells) # Save HRU ID as raster
#
# Cell In[18], line 23, in printHRUIDs(fp, sbc, hrus, cells)
#      20         t = cells[c]
#      21         d[c] = tt[sid][t]
# ---> 23 saveBinaryInt(fp,d)
#
# Cell In[7], line 51, in saveBinaryInt(fp, dat)
#      49     a = np.full((nrows,ncols),-9999,dtype=np.int32)
#      50     for cid,v in dat.items(): a[crc(cid)] = np.int32(v)
# ---> 51     if os.path.exists(fp): os.remove(fp)
#      52     a.tofile(fp) # always saved in C-order (row-major)
#      53 # elif type(dat)==np.ndarray:
#      54 #     if os.path.exists(fp): os.remove(fp)
#      55 #     dat.tofile(fp)
#      56 else:
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: '../GIS/CH_Landuse_dissolved-hruid.bil'

# %% [markdown]
# ## Printing Raven HRU specifications
#
# Print the HRU lines to be copied into the _*.rvh_ file

# %%
def rad2deg(rad): return (rad/math.pi*180.) % 360 # note Raven aspect is specified as degrees Counter-Clockwise from the North (i.e., west=90°)
def printRVH(f,ln):
    print(ln)
    f.write(ln+'\n')

# %%
f = open(lufp[:-4]+'-rvh.txt', "w")
print('Writing to: '+lufp[:-4]+'-rvh.txt\n')

printRVH(f,':HRUs')
printRVH(f,' :Attributes      AREA ELEVATION  LATITUDE LONGITUDE  BASIN_ID      LAND_USE_CLASS           VEG_CLASS        SOIL_PROFILE AQUIFER_PROFILE  TERRAIN_CLASS     SLOPE    ASPECT') # aspect deg CCWN (west=90°)
printRVH(f,' :Units            km2         m       deg       deg      none                none                none                none            none           none       deg      degN')
c = 0

for sid,lusg in hrus.items(): # write lake hrus first
    if lusg=='lake':
        ll = llzga[sid]
        km2 = len(xsb[sid])*cs*cs/1000000
        c+=1
        printRVH(f,'  {:<10}{:10.4f}{:10.1f}{:10.4f}{:10.4f}{:10}{:>20}{:>20}{:>20}          [NONE]         [NONE]{:10.3f}{:10.3f}'.format(c,km2,ll[2],ll[0],ll[1],sid,'LAKE','LAKE','LAKE',0.,0.))

for sid,lusg in hrus.items():
    if lusg=='lake': continue
    ll = llzga[sid]
    km2 = len(xsb[sid])*cs*cs/1000000
    for k,frac in lusg.items():
        c += 1
        printRVH(f,'  {:<10}{:10.4f}{:10.1f}{:10.4f}{:10.4f}{:10}{:>20}{:>20}{:>20}          [NONE]         [NONE]{:10.3f}{:10.3f}'.format(c,km2*frac,ll[k][2],ll[k][0],ll[k][1],sid,k[0][0],k[0][1],k[1],rad2deg(ll[k][3]),rad2deg(ll[k][4]-math.pi/2)))

printRVH(f,':EndHRUs')
f.close()
# Out:
# Writing to: ../GIS/CH_Landuse_dissolved-rvh.txt
#
# :HRUs
#  :Attributes      AREA ELEVATION  LATITUDE LONGITUDE  BASIN_ID      LAND_USE_CLASS           VEG_CLASS        SOIL_PROFILE AQUIFER_PROFILE  TERRAIN_CLASS     SLOPE    ASPECT
#  :Units            km2         m       deg       deg      none                none                none                none            none           none       deg      degN
#   1             2.2212     298.3   43.4603  -80.0442        64                LAKE                LAKE                LAKE          [NONE]         [NONE]     0.000     0.000
#   2             0.1944     281.0   43.5105  -79.9661        67                LAKE                LAKE                LAKE          [NONE]         [NONE]     0.000     0.000
#   3             0.3816     230.2   43.5100  -79.9467        65                LAKE                LAKE                LAKE          [NONE]         [NONE]     0.000     0.000
#   4             0.4212     252.3   43.5727  -79.9480        69                LAKE                LAKE                LAKE          [NONE]         [NONE]     0.000     0.000
#   5             7.3152     178.8   43.5106  -79.7255         1         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.065   264.209
#   6             2.3940     173.1   43.5124  -79.7104         1     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.630   223.678
#   7             6.9480     129.2   43.4948  -79.6752         1     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.715   245.259
#   8             2.4228     167.7   43.5034  -79.7042         1               Urban                Bare                 Low          [NONE]         [NONE]     1.751   258.094
#   9             1.1844     165.7   43.5043  -79.7091         1              Forest           Deciduous                 Low          [NONE]         [NONE]     2.030   273.199
#   10            1.5480     119.5   43.4900  -79.6664         1               Urban                Bare             Unknown          [NONE]         [NONE]     1.602   236.686
#   11            2.8116      90.4   43.4732  -79.6476         2               Urban                Bare                High          [NONE]         [NONE]     1.328   239.547
#   12            0.8820     105.6   43.4753  -79.6673         2     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.679   246.790
#   13            0.3132     127.3   43.4814  -79.6754         2              Forest           Deciduous             Unknown          [NONE]         [NONE]     3.692   260.096
#   14            0.9108     108.4   43.4759  -79.6708         2               Urban                Bare             Unknown          [NONE]         [NONE]     1.363   241.501
#   15            0.3996     104.8   43.4736  -79.6701         2              Barren                Bare             Unknown          [NONE]         [NONE]     1.456   246.127
#   16            0.4104      89.8   43.4725  -79.6500         2              Forest           Deciduous                High          [NONE]         [NONE]     1.635   239.079
#   17            0.3816      91.8   43.4723  -79.6511         2              Barren                Bare                High          [NONE]         [NONE]     1.279   238.089
#   18            3.6972     173.2   43.4687  -79.7721         3         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.428   237.143
#   19            5.7204     119.9   43.4568  -79.7224         3     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     4.084   231.487
#   20            6.0984     150.0   43.4651  -79.7315         3               Urban                Bare                 Low          [NONE]         [NONE]     1.694   219.332
#   21            1.4472     155.6   43.4666  -79.7388         3              Barren                Bare                 Low          [NONE]         [NONE]     1.714   220.684
#   22            2.3040     163.3   43.4673  -79.7538         3     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     2.421   218.093
#   23            2.6568     161.2   43.4655  -79.7601         3              Forest           Deciduous                 Low          [NONE]         [NONE]     4.638   247.651
#   24            1.8648     127.3   43.4584  -79.7390         3              Forest           Deciduous             Unknown          [NONE]         [NONE]     9.390   246.662
#   25            1.2420     247.2   43.4183  -79.8801         4     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     6.163    26.581
#   26            2.7936     249.6   43.4203  -79.8836         4              Forest           Deciduous                 Low          [NONE]         [NONE]     4.210    25.494
#   27            3.8376     215.2   43.4271  -79.8878         4         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     2.553   350.167
#   28            0.9000     265.1   43.4124  -79.8814         4               Urban                Bare                 Low          [NONE]         [NONE]     2.736     9.357
#   29            0.8748     210.0   43.4254  -79.8832         4     ShortVegetation     MixedVegetation                 Low          [NONE]         [NONE]     3.820   352.738
#   30            0.7992     267.1   43.4143  -79.8865         4     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     4.065    76.392
#   31            2.2176     114.3   43.4407  -79.7080         5     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.588   240.099
#   32            1.0368     162.6   43.4521  -79.7709         5         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.049   251.481
#   33            0.9036     129.6   43.4443  -79.7243         5     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.013   238.150
#   34            5.0976     118.8   43.4410  -79.7135         5               Urban                Bare                 Low          [NONE]         [NONE]     1.008   239.209
#   35            0.8676     122.2   43.4420  -79.7165         5              Barren                Bare                 Low          [NONE]         [NONE]     0.906   238.356
#   36            1.2600     107.9   43.4379  -79.7037         5               Urban                Bare             Unknown          [NONE]         [NONE]     1.484   220.967
#   37            1.0080      86.4   43.4320  -79.6815         5               Urban                Bare                High          [NONE]         [NONE]     1.614   255.950
#   38            5.5692     273.6   43.3925  -80.0611         6     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.523   186.130
#   39            0.7164     282.2   43.4012  -80.0677         6     ShortVegetation     ShortVegetation           LowMedium          [NONE]         [NONE]     2.782   193.045
#   40            0.7308     281.4   43.3961  -80.0562         6               Urban                Bare           LowMedium          [NONE]         [NONE]     2.506    47.245
#   41            2.3292     280.1   43.3888  -80.0641         6         Agriculture     ShortVegetation           LowMedium          [NONE]         [NONE]     3.048     6.105
#   42            1.7676     271.4   43.3948  -80.0724         6               Swamp     MixedVegetation    WetlandSediments          [NONE]         [NONE]     0.248   203.714
#   43            1.1556     271.7   43.3952  -80.0663         6               Swamp     MixedVegetation             Unknown          [NONE]         [NONE]     0.751   163.793
#   44            1.0908     273.5   43.3915  -80.0644         6         Agriculture     ShortVegetation             Unknown          [NONE]         [NONE]     1.534   167.054
#   45            0.9576     271.0   43.3859  -80.0448         6         Agriculture     ShortVegetation                High          [NONE]         [NONE]     1.363   190.251
#   46            1.5444     160.7   43.4081  -79.8122         7         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.262   239.712
#   47            4.9032     138.5   43.4000  -79.7881         7               Urban                Bare                 Low          [NONE]         [NONE]     1.074   233.659
#   48            1.3140     151.5   43.4039  -79.8028         7              Forest           Deciduous                 Low          [NONE]         [NONE]     2.414   253.454
#   49            2.3904     143.0   43.4023  -79.7943         7     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.571   238.946
#   50            3.6540     107.5   43.3905  -79.7500         7     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.321   243.857
#   51            0.9936     143.6   43.4019  -79.7953         7              Barren                Bare                 Low          [NONE]         [NONE]     1.320   241.390
#   52            2.8944     104.2   43.3880  -79.7475         7               Urban                Bare             Unknown          [NONE]         [NONE]     1.204   232.772
#   53            1.1592     119.2   43.3372  -79.8305         8     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     2.604   231.285
#   54            1.2744     148.9   43.3431  -79.8401         8               Urban                Bare                 Low          [NONE]         [NONE]     3.625   248.293
#   55            0.2664     150.1   43.3415  -79.8422         8              Forest           Deciduous             Unknown          [NONE]         [NONE]     3.718   247.246
#   56            0.5112     187.7   43.3435  -79.8518         8              Forest           Deciduous                 Low          [NONE]         [NONE]     5.517   257.644
#   57            0.4500     127.6   43.3394  -79.8336         8               Urban                Bare             Unknown          [NONE]         [NONE]     3.665   223.751
#   58            0.2592     107.5   43.3383  -79.8277         8              Barren                Bare             Unknown          [NONE]         [NONE]     2.719   230.453
#   59            0.4896      96.3   43.3304  -79.8210         8               Urban                Bare                High          [NONE]         [NONE]     1.086   223.096
#   60            0.3852      96.6   43.3284  -79.8230         8     ShortVegetation     ShortVegetation                High          [NONE]         [NONE]     1.652   231.749
#   61            1.4868     116.4   43.3521  -79.7993         9     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.731   227.923
#   62            3.3840     139.1   43.3658  -79.8145         9               Urban                Bare                 Low          [NONE]         [NONE]     1.317   238.511
#   63            0.8352     135.8   43.3649  -79.8132         9     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.515   230.513
#   64            0.6516     139.2   43.3651  -79.8150         9              Barren                Bare                 Low          [NONE]         [NONE]     1.328   240.822
#   65            0.7272      98.3   43.3491  -79.7858         9               Urban                Bare             Unknown          [NONE]         [NONE]     1.183   219.841
#   66            2.4660      91.3   43.3448  -79.7844         9               Urban                Bare                High          [NONE]         [NONE]     0.751   229.320
#   67            0.3168      83.9   43.3315  -79.7891        10     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.797   202.618
#   68            2.5560      88.8   43.3346  -79.7940        10               Urban                Bare                High          [NONE]         [NONE]     0.695   217.710
#   69            0.4680      89.2   43.3348  -79.7943        10              Barren                Bare                High          [NONE]         [NONE]     0.770   214.343
#   70            0.2844      89.5   43.3353  -79.7939        10     ShortVegetation     ShortVegetation                High          [NONE]         [NONE]     0.753   233.042
#   71            0.7488     182.5   43.3263  -79.8720        11         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     3.720   221.581
#   72            1.1772     140.0   43.3168  -79.8665        11     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     3.726   219.266
#   73            0.5148     186.7   43.3263  -79.8710        11     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     3.385   203.655
#   74            1.4148     175.4   43.3242  -79.8709        11              Forest           Deciduous                 Low          [NONE]         [NONE]     5.219   210.572
#   75            0.5904     171.7   43.3233  -79.8725        11               Urban                Bare                 Low          [NONE]         [NONE]     4.024   208.859
#   76            0.7740     137.3   43.3180  -79.8648        11              Forest           Deciduous             Unknown          [NONE]         [NONE]     4.568   212.511
#   77            0.3204     160.0   43.3185  -79.8773        11              Forest           Deciduous                High          [NONE]         [NONE]     4.203   233.482
#   78            0.0828     102.5   43.2935  -79.8742        12              Barren                Bare                High          [NONE]         [NONE]     7.303    16.138
#   79            0.3060      90.4   43.2937  -79.8750        12              Forest           Deciduous                High          [NONE]         [NONE]    10.107    53.476
#   80            0.2376     102.5   43.2943  -79.8721        12               Urban                Bare                High          [NONE]         [NONE]     7.557    48.713
#   81            0.2484      83.4   43.2934  -79.8796        12     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     5.683   188.216
#   82            0.1512      80.1   43.2949  -79.8756        12              Forest           Deciduous           Streambed          [NONE]         [NONE]     4.313   161.465
#   83            0.1368      75.7   43.2946  -79.8760        12             Wetland     ShortVegetation           Streambed          [NONE]         [NONE]     0.525   149.959
#   84            0.1188      75.2   43.2915  -79.8799        12           Waterbody                Bare           Streambed          [NONE]         [NONE]     0.335    92.396
#   85            0.1548     102.7   43.2909  -79.8753        12     ShortVegetation     ShortVegetation                High          [NONE]         [NONE]     6.032    41.860
#   86            1.3356     187.0   43.3127  -79.8999        13               Urban                Bare                 Low          [NONE]         [NONE]     3.805   214.013
#   87            2.0232     166.1   43.3116  -79.8970        13              Forest           Deciduous                 Low          [NONE]         [NONE]     5.589   222.975
#   88            1.2204     176.1   43.3101  -79.8999        13     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     3.915   229.721
#   89            1.6920     135.3   43.3054  -79.8850        13     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     5.083   209.328
#   90            0.9684     142.7   43.3069  -79.8904        13              Forest           Deciduous             Unknown          [NONE]         [NONE]     7.676   219.892
#   91            0.4500     167.1   43.3080  -79.9001        13         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     3.534   232.376
#   92            1.2312     110.2   43.3465  -79.8149        14     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.670   221.862
#   93            0.5616     132.7   43.3568  -79.8227        14              Barren                Bare                 Low          [NONE]         [NONE]     1.819   223.011
#   94            2.6136     131.8   43.3560  -79.8235        14               Urban                Bare                 Low          [NONE]         [NONE]     1.562   226.924
#   95            0.6552     132.6   43.3580  -79.8216        14     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     2.174   222.512
#   96            0.7668     103.4   43.3449  -79.8106        14               Urban                Bare             Unknown          [NONE]         [NONE]     0.806   221.917
#   97            0.4500      97.9   43.3388  -79.8107        14               Urban                Bare                High          [NONE]         [NONE]     0.946   223.099
#   98            0.9864     114.2   43.3599  -79.7876        15     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.205   225.965
#   99            1.2780     210.9   43.3779  -79.8471        15              Forest           Deciduous                 Low          [NONE]         [NONE]     4.630   277.017
#   100           2.8116     153.2   43.3757  -79.8213        15               Urban                Bare                 Low          [NONE]         [NONE]     1.454   270.220
#   101           1.1160     209.9   43.3788  -79.8508        15         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     3.203   273.376
#   102           1.5732     167.8   43.3763  -79.8301        15     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     2.387   277.509
#   103           0.6264     149.8   43.3760  -79.8203        15              Barren                Bare                 Low          [NONE]         [NONE]     1.285   258.454
#   104           0.9828     103.1   43.3592  -79.7831        15               Urban                Bare             Unknown          [NONE]         [NONE]     1.070   217.126
#   105           1.0368      91.3   43.3519  -79.7723        15               Urban                Bare                High          [NONE]         [NONE]     0.799   220.101
#   106           3.1680     271.4   43.4015  -79.9094        16         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.817   174.667
#   107           0.8928     264.0   43.3981  -79.8972        16     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     3.250   240.744
#   108           1.6056     264.3   43.3961  -79.9029        16              Forest           Deciduous                 Low          [NONE]         [NONE]     2.578   242.772
#   109           2.9520     253.3   43.3938  -79.9050        16     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     3.057     8.594
#   110           0.7920     270.1   43.3988  -79.9093        16               Urban                Bare                 Low          [NONE]         [NONE]     2.212    26.360
#   111           0.7992     245.2   43.4064  -79.9224        16              Forest           Deciduous                High          [NONE]         [NONE]     6.401    11.543
#   112           0.9072     257.9   43.4023  -79.8881        16              noflow                Bare                 Low          [NONE]         [NONE]     2.549   133.631
#   113           0.8280     258.7   43.3993  -79.9192        16         Agriculture     ShortVegetation                High          [NONE]         [NONE]     2.477   260.574
#   114           0.6480     270.6   43.3950  -79.9007        16     ShortVegetation     MixedVegetation                 Low          [NONE]         [NONE]     2.234   155.332
#   115           2.0844     278.5   43.4290  -79.9821        17              Forest           Deciduous             Unknown          [NONE]         [NONE]     1.849   248.266
#   116           0.9360     278.2   43.4329  -79.9842        17               Swamp     MixedVegetation             Unknown          [NONE]         [NONE]     0.900   232.813
#   117           1.3824     270.5   43.4212  -79.9751        17     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.514   225.662
#   118           0.5400     278.3   43.4278  -79.9837        17         Agriculture     ShortVegetation             Unknown          [NONE]         [NONE]     1.612   228.748
#   119           0.5472     269.6   43.4258  -79.9775        17               Swamp     MixedVegetation    WetlandSediments          [NONE]         [NONE]     0.352   187.592
#   120           1.3248     267.2   43.4160  -79.9729        17         Agriculture     ShortVegetation                High          [NONE]         [NONE]     1.687   235.699
#   121           0.6516     268.8   43.4125  -79.9728        17              Forest           Deciduous                High          [NONE]         [NONE]     2.030   256.583
#   122           1.0296     268.5   43.4104  -79.9707        17               Urban                Bare                High          [NONE]         [NONE]     1.845   252.972
#   123           0.6588     261.2   43.4134  -79.9710        17               Swamp     MixedVegetation                High          [NONE]         [NONE]     1.166   250.101
#   124           0.7380     266.2   43.4145  -79.9672        17     ShortVegetation     MixedVegetation                High          [NONE]         [NONE]     1.814   155.310
#   125           1.0440     169.3   43.4873  -79.7246        18              Forest           Deciduous                 Low          [NONE]         [NONE]     1.702   230.992
#   126           1.6560     181.1   43.4907  -79.7416        18         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.101   239.073
#   127           1.7676     146.8   43.4772  -79.7026        18     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     2.148   225.993
#   128           6.8832     162.3   43.4824  -79.7138        18               Urban                Bare                 Low          [NONE]         [NONE]     1.326   215.695
#   129           1.4076     161.4   43.4816  -79.7133        18              Barren                Bare                 Low          [NONE]         [NONE]     1.315   215.554
#   130           1.6632     158.9   43.4800  -79.7144        18     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.326   225.440
#   131           1.9980     143.1   43.4766  -79.6906        18               Urban                Bare             Unknown          [NONE]         [NONE]     2.373   217.847
#   132          18.0972     299.2   43.4797  -80.0084        19     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.675   231.111
#   133           4.5180     316.1   43.4926  -80.0315        19         Agriculture     ShortVegetation           LowMedium          [NONE]         [NONE]     1.881   173.109
#   134           2.1708     315.0   43.4939  -80.0373        19              Forest           Deciduous           LowMedium          [NONE]         [NONE]     2.172   189.161
#   135           2.2824     305.3   43.4842  -80.0146        19         Agriculture     ShortVegetation             Unknown          [NONE]         [NONE]     1.691   220.791
#   136           2.6424     311.0   43.4942  -80.0434        19               Swamp     MixedVegetation           LowMedium          [NONE]         [NONE]     0.815   184.131
#   137           3.6792     293.9   43.4720  -80.0090        19               Swamp     MixedVegetation             Unknown          [NONE]         [NONE]     0.887   219.540
#   138           7.0740     293.4   43.4705  -79.9970        19              Forest           Deciduous             Unknown          [NONE]         [NONE]     1.887   241.093
#   139           0.9720     196.7   43.4029  -79.8455        20         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     2.760   263.034
#   140           3.8232     112.9   43.3805  -79.7660        20     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.235   237.675
#   141           3.8628     141.4   43.3898  -79.7988        20               Urban                Bare                 Low          [NONE]         [NONE]     1.072   235.017
#   142           0.9432     182.8   43.3978  -79.8339        20              Forest           Deciduous                 Low          [NONE]         [NONE]     3.388   258.806
#   143           1.3032     158.2   43.3930  -79.8125        20     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.833   246.561
#   144           3.2364      96.5   43.3742  -79.7506        20               Urban                Bare             Unknown          [NONE]         [NONE]     0.915   232.242
#   145           2.9988     255.0   43.3753  -79.9040        21     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     0.983   206.590
#   146           0.7020     257.7   43.3709  -79.9041        21               Urban                Bare                 Low          [NONE]         [NONE]     1.294   161.381
#   147           0.8388     261.9   43.3776  -79.8868        21     ShortVegetation     MixedVegetation                 Low          [NONE]         [NONE]     1.115   167.662
#   148           2.2896     260.7   43.3736  -79.9100        21         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.149   211.000
#   149           0.8208     257.0   43.3730  -79.8939        21              Forest           Deciduous                 Low          [NONE]         [NONE]     1.056   209.603
#   150           1.5984     259.6   43.3714  -79.9122        21         Agriculture     ShortVegetation                High          [NONE]         [NONE]     1.232   216.987
#   151           0.7128     251.5   43.3632  -79.9049        21               Urban                Bare                High          [NONE]         [NONE]     1.432   239.832
#   152           0.7632     248.5   43.3615  -79.8928        21              Forest           Deciduous                High          [NONE]         [NONE]     1.611    64.514
#   153           1.2564     245.3   43.3641  -79.8985        21               Swamp     MixedVegetation                High          [NONE]         [NONE]     0.475   185.851
#   154           0.9900     252.0   43.3625  -79.9090        21     ShortVegetation     ShortVegetation                High          [NONE]         [NONE]     1.016   236.941
#   155           0.8100     255.5   43.3735  -79.9022        21               Swamp     MixedVegetation                 Low          [NONE]         [NONE]     0.538   221.911
#   156           9.8100     285.2   43.4642  -79.9569        22              Forest           Deciduous             Unknown          [NONE]         [NONE]     3.843   199.710
#   157           2.7288     253.5   43.4571  -79.9256        22              Forest           Deciduous                 Low          [NONE]         [NONE]     4.037   225.677
#   158          14.2056     267.9   43.4650  -79.9404        22     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     2.670   233.223
#   159           6.4512     227.9   43.4482  -79.9164        22         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.899   278.393
#   160           2.2536     255.1   43.4611  -79.9449        22              Forest           Deciduous                High          [NONE]         [NONE]     3.723   202.767
#   161           1.9548     246.7   43.4616  -79.9399        22         Agriculture     ShortVegetation                High          [NONE]         [NONE]     1.630   203.051
#   162          24.0300     238.0   43.5847  -79.8874        23         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.528   226.730
#   163           3.1824     228.8   43.5798  -79.8775        23               Urban                Bare                 Low          [NONE]         [NONE]     1.745   219.588
#   164           2.7756     230.5   43.5785  -79.8881        23     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.359   261.215
#   165           5.6592     220.5   43.5743  -79.8767        23     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.484   230.689
#   166           2.2068     233.9   43.5837  -79.8855        23               Swamp     MixedVegetation                 Low          [NONE]         [NONE]     1.416   226.130
#   167           2.5596     232.5   43.5784  -79.8826        23              Forest           Deciduous                 Low          [NONE]         [NONE]     2.330   226.694
#   168           4.0716     201.6   43.5732  -79.7833        24     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.144   235.428
#   169           2.0700     200.8   43.5718  -79.7797        24              Barren                Bare                 Low          [NONE]         [NONE]     1.337   195.538
#   170           7.0992     198.1   43.5685  -79.7714        24               Urban                Bare                 Low          [NONE]         [NONE]     0.860   163.716
#   171           9.2592     199.6   43.5611  -79.7841        24         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     0.763   246.008
#   172           3.9024     191.7   43.5491  -79.7681        24     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     0.916   249.626
#   173           5.0508     232.4   43.5570  -79.9070        25     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.896   258.023
#   174           5.9364     224.9   43.5563  -79.9040        25         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.699   262.595
#   175           1.2060     224.9   43.5557  -79.9075        25               Swamp     MixedVegetation                 Low          [NONE]         [NONE]     2.085   256.740
#   176           1.0692     244.1   43.5602  -79.9322        25              Forest           Deciduous                 Low          [NONE]         [NONE]     3.408   255.741
#   177           1.4292     248.3   43.5570  -79.9412        25     ShortVegetation     MixedVegetation                 Low          [NONE]         [NONE]     2.889   270.982
#   178           1.9440     217.4   43.5514  -79.8943        25     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.832   289.323
#   179           2.3940     216.9   43.5515  -79.8892        25               Urban                Bare                 Low          [NONE]         [NONE]     1.878   306.674
#   180           1.1808     328.7   43.5620  -79.9654        25              Forest           Deciduous             Unknown          [NONE]         [NONE]     3.851   272.377
#   181           0.7380     207.3   43.4161  -79.8560        26     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     6.306   300.961
#   182           1.6308     224.0   43.4153  -79.8570        26              Forest           Deciduous                 Low          [NONE]         [NONE]     5.942   302.954
#   183           2.3364     195.6   43.4163  -79.8527        26         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     2.151   325.186
#   184           0.2880     190.9   43.4170  -79.8534        26               Urban                Bare                 Low          [NONE]         [NONE]     3.692   314.288
#   185           0.3780     104.3   43.4604  -79.6813        27              Barren                Bare             Unknown          [NONE]         [NONE]     1.606   229.489
#   186           0.9576     100.8   43.4611  -79.6756        27     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.916   246.582
#   187           1.4004     102.4   43.4608  -79.6790        27               Urban                Bare             Unknown          [NONE]         [NONE]     1.321   235.589
#   188           2.9772      88.7   43.4568  -79.6626        27               Urban                Bare                High          [NONE]         [NONE]     1.290   243.912
#   189           0.4032      89.0   43.4555  -79.6644        27              Barren                Bare                High          [NONE]         [NONE]     1.325   251.975
#   190           4.5648     191.5   43.5498  -79.7827        28         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     0.531   196.446
#   191           1.7352     189.1   43.5404  -79.7724        28     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     0.961   143.543
#   192           0.4716     192.9   43.5498  -79.7820        28               Urban                Bare                 Low          [NONE]         [NONE]     0.942   200.912
#   193           0.7236     186.0   43.5306  -79.7683        28     ShortVegetation     MixedVegetation                 Low          [NONE]         [NONE]     1.055   100.196
#   194           0.4716     189.2   43.5429  -79.7720        28         Agriculture     ShortVegetation                High          [NONE]         [NONE]     0.845   139.661
#   195           0.1764     249.4   43.3507  -79.8864        29         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     0.866   136.527
#   196           0.8640     240.4   43.3423  -79.8908        29               Urban                Bare                 Low          [NONE]         [NONE]     2.123   191.084
#   197           0.1656     239.8   43.3423  -79.8900        29              Barren                Bare                 Low          [NONE]         [NONE]     2.247   180.294
#   198           0.1908     231.3   43.3398  -79.8916        29     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     3.363   190.677
#   199           0.1224     232.1   43.3424  -79.8909        29              Forest           Deciduous                 Low          [NONE]         [NONE]     2.592   182.238
#   200           0.2196     241.6   43.3439  -79.8908        29     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     2.640   115.815
#   201           0.1440     239.8   43.3397  -79.8970        29               Urban                Bare                High          [NONE]         [NONE]     1.879   245.431
#   202           0.1080     239.7   43.3385  -79.8990        29     ShortVegetation     ShortVegetation                High          [NONE]         [NONE]     1.463   208.057
#   203           0.7416     258.8   43.3702  -79.9450        30               Swamp     MixedVegetation                High          [NONE]         [NONE]     0.291   203.099
#   204           0.5364     262.6   43.3642  -79.9480        30     ShortVegetation     ShortVegetation                High          [NONE]         [NONE]     1.547   137.644
#   205           1.3032     261.1   43.3671  -79.9465        30     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.041   186.971
#   206           3.2832     263.1   43.3560  -79.9523        30         Agriculture     ShortVegetation                High          [NONE]         [NONE]     1.176   237.433
#   207           0.5148     264.0   43.3644  -79.9500        30     ShortVegetation     MixedVegetation                High          [NONE]         [NONE]     1.592   270.585
#   208           1.2420     260.9   43.3547  -79.9503        30               Urban                Bare                High          [NONE]         [NONE]     1.482   224.005
#   209           0.4464     262.5   43.3562  -79.9448        30         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.259   237.214
#   210           1.6380     265.5   43.3775  -79.8734        31              Forest           Deciduous                 Low          [NONE]         [NONE]     1.164   171.781
#   211           1.2816     256.6   43.3627  -79.8762        31               Urban                Bare                 Low          [NONE]         [NONE]     1.510   172.747
#   212           0.9900     258.8   43.3682  -79.8755        31     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.177   168.583
#   213           2.7720     266.6   43.3771  -79.8713        31         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.526   162.610
#   214           0.9144     254.4   43.3640  -79.8760        31     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.441   163.557
#   215           0.7920     267.7   43.3833  -79.8797        31     ShortVegetation     MixedVegetation                 Low          [NONE]         [NONE]     1.622   198.788
#   216          10.0980     187.6   43.4888  -79.8233        32         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.086   216.160
#   217           2.4696     178.5   43.4913  -79.8310        32     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     3.457   223.079
#   218           1.7712     195.6   43.5029  -79.8560        32              Barren                Bare                 Low          [NONE]         [NONE]     0.971   226.069
#   219          10.6200     196.5   43.5042  -79.8582        32               Urban                Bare                 Low          [NONE]         [NONE]     1.051   220.305
#   220           2.4696     197.0   43.5056  -79.8598        32     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.522   202.827
#   221           1.7136     182.0   43.4860  -79.8254        32              Forest           Deciduous                 Low          [NONE]         [NONE]     4.250   274.469
#   222           2.4948     179.1   43.4791  -79.8140        32     ShortVegetation     MixedVegetation                 Low          [NONE]         [NONE]     1.853   233.362
#   223           1.9224     229.5   43.6030  -79.8587        33     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.438   235.791
#   224           3.0744     234.1   43.6103  -79.8688        33               Urban                Bare                 Low          [NONE]         [NONE]     1.113   226.150
#   225           6.6816     212.6   43.5826  -79.8378        33     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.078   214.719
#   226          19.0296     228.4   43.5982  -79.8559        33         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.019   204.221
#   227           1.8504     178.7   43.4889  -79.7729        34     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     3.466   176.147
#   228           5.0508     187.8   43.4963  -79.7857        34         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     0.953   239.307
#   229           0.9756     181.0   43.4886  -79.7689        34              Forest           Deciduous                 Low          [NONE]         [NONE]     7.247    64.019
#   230           0.6984     189.3   43.4963  -79.7721        34               Urban                Bare                 Low          [NONE]         [NONE]     1.302   133.912
#   231           0.5760     168.8   43.4885  -79.7739        34              Forest           Deciduous             Unknown          [NONE]         [NONE]     8.026   204.936
#   232           0.3960     217.9   43.3292  -79.8888        35               Urban                Bare                 Low          [NONE]         [NONE]     6.112   236.702
#   233           0.5364     179.4   43.3223  -79.8802        35     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     6.318   211.355
#   234           0.1872     183.1   43.3211  -79.8845        35     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     7.868   264.032
#   235           0.6336     145.7   43.3188  -79.8821        35              Forest           Deciduous             Unknown          [NONE]         [NONE]     9.202   174.266
#   236           0.1620     202.4   43.3251  -79.8918        35     ShortVegetation     ShortVegetation                High          [NONE]         [NONE]     3.442   219.660
#   237           0.3060     164.0   43.3218  -79.8875        35              Forest           Deciduous                 Low          [NONE]         [NONE]    12.665   263.303
#   238           0.3456     208.0   43.3264  -79.8908        35               Urban                Bare                High          [NONE]         [NONE]     3.012   254.970
#   239           0.3708     150.6   43.3162  -79.8818        35              Forest           Deciduous                High          [NONE]         [NONE]    16.371    88.746
#   240           0.5400     254.0   43.3582  -79.8625        36         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     3.709   260.833
#   241           0.6372     195.2   43.3582  -79.8485        36     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     2.251   251.958
#   242           0.2448     228.4   43.3565  -79.8581        36     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     6.153   269.231
#   243           1.1484     212.5   43.3564  -79.8539        36              Forest           Deciduous                 Low          [NONE]         [NONE]     4.161   259.517
#   244           2.2752     182.8   43.3574  -79.8462        36               Urban                Bare                 Low          [NONE]         [NONE]     2.824   256.842
#   245           0.2988     181.1   43.3585  -79.8449        36              Barren                Bare                 Low          [NONE]         [NONE]     2.626   244.694
#   246           0.3204     171.7   43.3504  -79.8456        36     ShortVegetation     MixedVegetation                 Low          [NONE]         [NONE]     3.737   264.559
#   247           0.5832     178.8   43.3042  -79.9101        37     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     3.243   224.439
#   248           0.1764     163.5   43.3027  -79.9059        37              Barren                Bare                 Low          [NONE]         [NONE]     3.228   209.098
#   249           0.7560     127.9   43.2959  -79.9008        37     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     6.430   216.745
#   250           0.5508     176.9   43.3039  -79.9103        37               Urban                Bare                 Low          [NONE]         [NONE]     2.914   210.057
#   251           0.2088     174.0   43.3018  -79.9100        37         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     3.417   235.382
#   252           0.3960     151.2   43.2999  -79.9081        37              Forest           Deciduous                 Low          [NONE]         [NONE]     4.959   217.986
#   253           0.1908     124.6   43.2954  -79.9002        37              Forest           Deciduous             Unknown          [NONE]         [NONE]     9.691   221.804
#   254           0.5148     106.3   43.4820  -79.6668        38               Urban                Bare             Unknown          [NONE]         [NONE]     0.628   281.931
#   255           0.0684     106.5   43.4806  -79.6675        38     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.750   241.072
#   256           0.0756     105.4   43.4794  -79.6660        38              Barren                Bare             Unknown          [NONE]         [NONE]     1.380   236.328
#   257           5.0940     200.8   43.4857  -79.8759        39               Urban                Bare                 Low          [NONE]         [NONE]     1.438   218.838
#   258           3.6288     218.0   43.4712  -79.8874        39              Forest           Deciduous                 Low          [NONE]         [NONE]     3.295   261.734
#   259          25.8084     192.8   43.4623  -79.8665        39         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.147   241.786
#   260           2.8188     224.7   43.4723  -79.8834        39     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     4.680   239.114
#   261           2.0880     195.3   43.4814  -79.8679        39     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.134   210.676
#   262          29.4192     315.5   43.5344  -79.9985        40     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     2.353   249.979
#   263           5.4180     350.8   43.5648  -80.0283        40         Agriculture     ShortVegetation           LowMedium          [NONE]         [NONE]     2.791   213.165
#   264           4.1184     337.4   43.5496  -80.0177        40              Forest           Deciduous           LowMedium          [NONE]         [NONE]     2.675   228.870
#   265           5.0760     344.4   43.5639  -80.0315        40               Swamp     MixedVegetation           LowMedium          [NONE]         [NONE]     0.901   219.251
#   266           6.1596     324.2   43.5420  -80.0012        40               Swamp     MixedVegetation             Unknown          [NONE]         [NONE]     1.083   203.697
#   267          14.0688     323.2   43.5388  -79.9916        40              Forest           Deciduous             Unknown          [NONE]         [NONE]     2.654   221.755
#   268           0.3024      87.0   43.3250  -79.8066        41     ShortVegetation     ShortVegetation                High          [NONE]         [NONE]     0.975   223.363
#   269           1.4436      88.0   43.3255  -79.8065        41               Urban                Bare                High          [NONE]         [NONE]     0.802   236.690
#   270           0.0432      91.4   43.3291  -79.8129        41     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.080   194.465
#   271           0.2700      87.0   43.3251  -79.8048        41              Barren                Bare                High          [NONE]         [NONE]     0.991   235.702
#   272           0.8676     149.0   43.2930  -79.9209        42     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     3.818   189.572
#   273           1.0476     103.3   43.2846  -79.9117        42     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     4.884   204.626
# ...
#   330           3.9240     253.2   43.3531  -79.9859        50               Swamp     MixedVegetation                High          [NONE]         [NONE]     0.223   140.630
#   331           1.4688     251.5   43.3495  -80.0031        50               Swamp     MixedVegetation    WetlandSediments          [NONE]         [NONE]     0.077   140.772
#   332           0.4176      87.2   43.2988  -79.8545        51              Forest           Deciduous                High          [NONE]         [NONE]     6.206   222.393
#   333           0.2880     102.5   43.3054  -79.8554        51              Barren                Bare                High          [NONE]         [NONE]     1.921   267.062
#   334           0.4248      96.8   43.3002  -79.8618        51     ShortVegetation     ShortVegetation                High          [NONE]         [NONE]     3.780   207.788
#   335           3.4164      97.3   43.3019  -79.8540        51               Urban                Bare                High          [NONE]         [NONE]     2.879   231.822
#   336           0.0684      84.5   43.2895  -79.8751        51     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     3.843   206.222
#   337           0.0324      98.3   43.2877  -79.8897        52               Urban                Bare                High          [NONE]         [NONE]    10.241   246.267
#   338           0.0720      95.5   43.2842  -79.8906        52              Barren                Bare                High          [NONE]         [NONE]    11.564   247.489
#   339           0.1188      94.5   43.2849  -79.8907        52              Forest           Deciduous                High          [NONE]         [NONE]     8.227   252.401
#   340           0.0180      76.8   43.2840  -79.8889        52     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     2.014   314.981
#   341           0.0468      94.3   43.2840  -79.8913        52     ShortVegetation     ShortVegetation                High          [NONE]         [NONE]     6.853    25.529
#   342           1.2240     255.0   43.3586  -79.9258        53     ShortVegetation     ShortVegetation                High          [NONE]         [NONE]     1.227   227.934
#   343           2.2932     253.6   43.3521  -79.9324        53         Agriculture     ShortVegetation                High          [NONE]         [NONE]     1.216   215.532
#   344           0.5148     254.7   43.3556  -79.9280        53               Urban                Bare                High          [NONE]         [NONE]     1.466   164.814
#   345           0.4500     253.4   43.3454  -79.9395        53     ShortVegetation     MixedVegetation                High          [NONE]         [NONE]     1.313   225.053
#   346           1.5696     252.3   43.3533  -79.9234        53     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.299   246.882
#   347           0.5328     247.0   43.3533  -79.9173        53               Swamp     MixedVegetation                High          [NONE]         [NONE]     0.426   221.977
#   348           1.0476     256.6   43.3594  -79.9233        53         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.138   233.441
#   349           0.5184     256.9   43.3574  -79.9248        53     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.334   248.151
#   350           0.2052     251.4   43.3353  -79.9542        54               Urban                Bare                High          [NONE]         [NONE]     1.152   184.380
#   351           0.1332     250.2   43.3335  -79.9525        54     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     0.796   312.726
#   352           0.0648     251.1   43.3338  -79.9506        54     ShortVegetation     ShortVegetation                High          [NONE]         [NONE]     1.231    19.002
#   353           0.1656     251.8   43.3309  -79.9533        54         Agriculture     ShortVegetation                High          [NONE]         [NONE]     1.003   350.186
#   354           0.0612     250.3   43.3330  -79.9519        54              Forest           Deciduous                High          [NONE]         [NONE]     1.153   303.940
#   355           0.0648     252.0   43.3317  -79.9467        54               Urban                Bare                 Low          [NONE]         [NONE]     1.211    95.030
#   356           0.0432     251.7   43.3311  -79.9479        54     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.165    88.821
#   357           0.0936     251.7   43.3295  -79.9485        54         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.256    33.302
#   358           0.1188      92.1   43.3029  -79.8639        55              Forest           Deciduous                High          [NONE]         [NONE]     5.243    73.215
#   359           0.2160     102.0   43.3027  -79.8632        55               Urban                Bare                High          [NONE]         [NONE]     5.055   104.821
#   360           0.0540      87.3   43.3031  -79.8654        55              Forest           Deciduous           Streambed          [NONE]         [NONE]     3.647   157.575
#   361           0.0864      98.7   43.3036  -79.8668        55     ShortVegetation     ShortVegetation                High          [NONE]         [NONE]     3.864   256.909
#   362           0.0612     101.7   43.3026  -79.8679        55              Barren                Bare                High          [NONE]         [NONE]     5.953   251.436
#   363           0.0504      86.5   43.3035  -79.8629        55     ShortVegetation     ShortVegetation           Streambed          [NONE]         [NONE]     1.215   164.551
#   364           0.0432      90.1   43.3026  -79.8648        55     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     4.887   185.268
#   365           7.3584     237.9   43.5212  -79.9227        56     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     3.838   281.793
#   366           5.7348     226.2   43.5229  -79.9160        56     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     2.203   269.932
#   367           4.7052     226.5   43.5267  -79.9285        56         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.361   268.262
#   368           6.5592     214.4   43.5277  -79.9056        56               Urban                Bare                 Low          [NONE]         [NONE]     1.205   235.077
#   369           1.8864     246.6   43.5166  -79.9275        56              Forest           Deciduous                 Low          [NONE]         [NONE]     5.818   312.560
#   370           9.5256     189.3   43.5295  -79.8116        57     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.454   257.133
#   371          14.5836     191.6   43.5217  -79.8075        57         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     0.745   281.076
#   372           2.5956     197.8   43.5306  -79.8353        57     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.076   277.716
#   373           6.1632     200.9   43.5252  -79.8431        57               Urban                Bare                 Low          [NONE]         [NONE]     0.921   247.211
#   374          10.0656     165.5   43.4380  -79.7995        58         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     1.635   242.699
#   375           5.4684     139.9   43.4308  -79.7554        58               Urban                Bare                 Low          [NONE]         [NONE]     1.422   221.395
#   376           2.4804     155.7   43.4369  -79.7839        58              Forest           Deciduous                 Low          [NONE]         [NONE]     1.899   233.252
#   377           3.1176     118.0   43.4242  -79.7357        58     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.861   252.068
#   378           1.4796     146.4   43.4330  -79.7669        58              Barren                Bare                 Low          [NONE]         [NONE]     1.558   231.732
#   379           2.4192     140.2   43.4291  -79.7615        58     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     1.564   242.903
#   380           0.5940     261.8   43.3924  -79.9723        59              Forest           Deciduous                High          [NONE]         [NONE]     1.972    81.054
#   381           1.9728     263.5   43.3951  -79.9747        59               Urban                Bare                High          [NONE]         [NONE]     1.701   287.111
#   382           1.1088     269.0   43.3878  -79.9695        59     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     3.464    17.859
#   383           0.4356     256.5   43.3922  -79.9744        59               Swamp     MixedVegetation                High          [NONE]         [NONE]     1.124   356.333
#   384           1.4544     262.5   43.3874  -79.9715        59         Agriculture     ShortVegetation                High          [NONE]         [NONE]     0.975    34.585
#   385           0.4248     262.8   43.3893  -79.9747        59     ShortVegetation     ShortVegetation                High          [NONE]         [NONE]     1.654    53.805
#   386           3.3480     201.9   43.4354  -79.8929        60         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     2.558   205.065
#   387           4.8456     232.1   43.4168  -79.9276        60     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     2.836   270.355
#   388           1.3500     208.7   43.4275  -79.9088        60              Forest           Deciduous                 Low          [NONE]         [NONE]     6.522   279.169
#   389           1.8972     236.7   43.4114  -79.9336        60              Forest           Deciduous                High          [NONE]         [NONE]     7.329     8.844
#   390           2.5128     265.7   43.3974  -79.9464        60         Agriculture     ShortVegetation                High          [NONE]         [NONE]     1.300   119.015
#   391           1.1628     238.1   43.4028  -79.9434        60               Swamp     MixedVegetation                High          [NONE]         [NONE]     4.039   359.777
#   392           0.3096     281.1   43.4088  -80.0043        61         Agriculture     ShortVegetation           LowMedium          [NONE]         [NONE]     3.151   188.278
#   393           0.5868     271.4   43.4016  -80.0007        61     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.688   193.277
#   394           1.6920     270.4   43.3988  -80.0023        61         Agriculture     ShortVegetation                High          [NONE]         [NONE]     1.397   218.024
#   395           0.3060     270.6   43.3997  -79.9981        61               Urban                Bare                High          [NONE]         [NONE]     1.276   154.217
#   396           0.4464     267.2   43.3990  -79.9986        61     ShortVegetation     ShortVegetation                High          [NONE]         [NONE]     1.385   196.511
#   397           0.2376     265.8   43.3967  -80.0001        61              Forest           Deciduous                High          [NONE]         [NONE]     1.657   210.052
#   398           2.2716     334.2   43.5092  -80.0720        62     ShortVegetation     ShortVegetation           LowMedium          [NONE]         [NONE]     2.313    74.405
#   399           4.3128     336.2   43.5210  -80.0678        62              Forest           Deciduous           LowMedium          [NONE]         [NONE]     2.240   220.551
#   400           3.2076     322.7   43.5096  -80.0647        62               Swamp     MixedVegetation           LowMedium          [NONE]         [NONE]     0.946   196.660
#   401          10.4292     335.4   43.5189  -80.0715        62         Agriculture     ShortVegetation           LowMedium          [NONE]         [NONE]     1.993   242.698
#   402           9.1152     322.9   43.5071  -80.0689        62     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.341   224.557
#   403           2.0520     330.0   43.5119  -80.0615        62               Urban                Bare           LowMedium          [NONE]         [NONE]     2.422   210.623
#   404           1.9080     310.6   43.4906  -80.0695        62               Swamp     MixedVegetation    WetlandSediments          [NONE]         [NONE]     0.249   220.940
#   405           3.9204     301.9   43.4429  -80.0243        63         Agriculture     ShortVegetation           LowMedium          [NONE]         [NONE]     3.205   294.253
#   406           6.6024     289.0   43.4342  -80.0120        63     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     1.829   182.992
#   407           1.1916     298.7   43.4432  -80.0250        63              Forest           Deciduous           LowMedium          [NONE]         [NONE]     4.093   301.299
#   408           3.1716     286.2   43.4348  -80.0103        63              Forest           Deciduous             Unknown          [NONE]         [NONE]     1.306   200.598
#   409           2.2752     285.1   43.4356  -80.0153        63               Swamp     MixedVegetation             Unknown          [NONE]         [NONE]     0.743   181.417
#   410           1.2492     290.4   43.4387  -80.0192        63         Agriculture     ShortVegetation             Unknown          [NONE]         [NONE]     1.906   212.104
#   411           2.1348     317.2   43.5342  -79.9679        66              Forest           Deciduous             Unknown          [NONE]         [NONE]     3.989   243.300
#   412           0.5544     317.4   43.5378  -79.9691        66               Swamp     MixedVegetation             Unknown          [NONE]         [NONE]     2.968   206.504
#   413           1.8324     313.4   43.5353  -79.9679        66     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     2.903   243.996
#   414           1.2384     309.2   43.5414  -79.9623        66              noflow                Bare             Unknown          [NONE]         [NONE]     2.768   159.298
#   415           1.1628     305.0   43.5340  -79.9678        66           Waterbody                Bare             Unknown          [NONE]         [NONE]     0.596   272.847
#   416           2.7612     297.0   43.6102  -79.9602        68     ShortVegetation     ShortVegetation                 Low          [NONE]         [NONE]     2.164   285.176
#   417          17.4024     311.1   43.6027  -79.9714        68     ShortVegetation     ShortVegetation             Unknown          [NONE]         [NONE]     2.388   264.400
#   418           6.8652     290.5   43.5957  -79.9555        68         Agriculture     ShortVegetation                 Low          [NONE]         [NONE]     2.345   271.872
#   419           5.7636     340.6   43.5971  -79.9815        68              Forest           Deciduous             Unknown          [NONE]         [NONE]     2.934   275.805
#   420           2.8332     343.0   43.5959  -79.9871        68               Swamp     MixedVegetation             Unknown          [NONE]         [NONE]     1.090   244.995
# :EndHRUs
